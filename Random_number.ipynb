# %% [markdown]
# # 1. LCG random generator with the following set of parameters a = 1103515245, c = 12345, m = 32768.

# %%
import Library.assign2 as lib
lib.My_random(10,100,0)
# Out:
# [0.503753662109375,
#  0.09371527936309576,
#  0.3899068179339338,
#  0.11763670457003172,
#  0.9824787778070458,
#  0.9340270703978604,
#  0.24464192892992287,
#  0.08823060230861302,
#  0.6845618617753644,
#  0.10142867118338472,
#  0.15081576407555985,
#  0.3408155427132442,
#  0.8897740787851944,
#  0.9537825101651833,
#  0.5409357192147581,
#  0.25945185928503633,
#  0.8365193064091727,
#  0.5134387008147314,
#  0.25301275787569466,
#  0.989394998867283,
#  0.8489250733764493,
#  0.2976481218065601,
#  0.1572588853759953,
#  0.32331616572173516,
#  0.5700326196656533,
#  0.1444991557400499,
#  0.6188430412084927,
#  0.9141612467901723,
#  0.23099429817011696,
#  0.48225521239237423,
#  0.09875047906098189,
#  0.958376917932128,
#  0.26502667898967047,
#  0.5775633795947215,
#  0.7549846343099489,
#  0.7018646783035365,
#  0.8016795340954559,
#  0.22791988625613158,
#  0.9464759004877124,
#  0.4790714506088989,
#  0.8804379633929784,
#  0.5450403107788588,
# ...

# %% [markdown]
# # 2. Calculate the volume of that part of a sphere of unit radius, centered at origin, which is in the first quadrant by throwing method.

# %%
lib.vol(100000)
# Out:
# 0.5245
# 0.5245

# %% [markdown]
# # 3. Simulate a 2-dimensional random walk

# %%
# 2d random walk
lib.steps(300)
lib.steps(600)
lib.steps(900)
# Out:
# RMS of step 300 is:  1.1228783967000935
# Displacement of step 300 is:  0.9683170055753423
# RMS of step 300 is 390.633197552886 times the Displacement
# RMS of step 600 is:  1.146196093910102
# Displacement of step 600 is:  0.9842945117841456
# RMS of step 600 is 800.836824730492 times the Displacement
# RMS of step 900 is:  1.1441656987578568
# Displacement of step 900 is:  0.2886057555221945
# RMS of step 900 is 4082.3982510703686 times the Displacement
